# %%
import rdlib4 as rd
import cv2
img = cv2.imread("Primrose.jpg",-1)

# %%
rd.storePkl(img,'Primrose.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8691cf95e58c> in <module>
# ----> 1 rd.storePkl(img, 'Primrose.pkl')
#
# ~\Documents\GitHub\RadiShLab\rdlib4.py in storePkl(val, fname, folder)
#     338     os.makedirs(folder, exist_ok=True)
#     339     f = open(folder+"/"+fname,'wb')
# --> 340     pickle.dump(cat,f)
#     341     f.close
#     342
#
# NameError: name 'cat' is not defined

# %%
rd.plotimg(img)

# %%
import japanize_kivy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-12008674cc47> in <module>
# ----> 1 import japanize_kivy
#
# ModuleNotFoundError: No module named 'japanize_kivy'

# %%
from kivy.app import App
from kivy.core.window import Window
# Out:
# [INFO   ] [Logger      ] Record log in /Users/dan/.kivy/logs/kivy_20-02-16_31.txt
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "/Users/dan/anaconda3/envs/RL/lib/python3.7/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# [INFO   ] [Python      ] Interpreter at "/Users/dan/anaconda3/envs/RL/bin/python"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_imageio, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL ES 2" graphics system
# [INFO   ] [GL          ] Backend used <sdl2>
# [INFO   ] [GL          ] OpenGL version <b'2.1 ATI-3.5.5'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon RX 580 OpenGL Engine'>
# ...

# %%
class MyApp(App):
    def build(self):
        return
    
MyApp().run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e5f7beb3596> in <module>
# ----> 1 class MyApp(App):
#       2     def build(self):
#       3         return
#       4
#       5 MyApp().run()
#
# NameError: name 'App' is not defined
