# %%
1

# %%
import rdlib4, cv2
#img = cv2.imread("Primrose.jpg",-1)
#storePkk(img, 'Primrose.pkl', folder = ".")

# %%
rdlib4.plotimg(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c6f089089ede> in <module>
# ----> 1 rdlib4.plotimg(img)
#
# NameError: name 'img' is not defined

# %%
img4 = rdlib4.loadPkl('Primrose.pkl')

# %%
rdlib4.plotimg(img4)
